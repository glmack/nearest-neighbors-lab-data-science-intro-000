# %% [markdown]
# # Nearest Neighbors Lab

# %% [markdown]
# ### Introduction
#
# In this lab, you apply nearest neighbors technique to help a taxi company predict the length of their rides.  Imagine that we are hired to consult for LiftOff, a limo and taxi service that is just opening up in NYC.  Liftoff wants it's taxi drivers to target longer rides, as the longer the ride the more money it makes.  LiftOff has the following theory:
#
# * the pickup location of a taxi ride can help predict the length of the ride.
#
#
#
# LiftOff asks us to do some analysis to write a function that will allow it to **predict the length of a taxi ride for any given location **.
#
# Our technique will be the following:
#   * **Collect** Obtain the data containing all of the taxi information, and only select the attributes of taxi trips that we need
#   * ** Explore ** Examine the attributes of our data, and plot some of our data on a map
#   * ** Train ** Write our nearest neighbors formula, and change the number of nearby trips to predict the length of a new trip
#   * ** Predict ** Use our function to predict trip lengths of new locations

# %% [markdown]
# ### Collect and Explore the data

# %% [markdown]
# #### Collect the Data

# %% [markdown]
# Luckily for us, [NYC Open Data](https://opendata.cityofnewyork.us/) collects information about NYC taxi trips and provides this data on [its website](https://data.cityofnewyork.us/Transportation/2014-Yellow-Taxi-Trip-Data/gn7m-em8n).

# %% [markdown]
# ![](./nyc-taxi.png)

# %% [markdown]
# For your reading pleasure, the data has already been downloaded into the [trips.json](https://github.com/learn-co-curriculum/nearest-neighbors-lab/blob/master/trips.json) file in this lab which you can find here.  We'll use Python's `json` library to take the data from the `trips.json` file and store it as a variable in our notebook.

# %%
import json
# First, read the file
trips_file = open('trips.json')
# Then, convert contents to list of dictionaries 
trips = json.load(trips_file)

# %%
import json

trips_file = open('trips.json')

trips = json.load(trips_file)
trips
# Out:
# [{'dropoff_datetime': '2014-11-26T22:31:00.000',
#   'dropoff_latitude': '40.746769999999998',
#   'dropoff_longitude': '-73.997450000000001',
#   'fare_amount': '52',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-26T21:59:00.000',
#   'pickup_latitude': '40.64499',
#   'pickup_longitude': '-73.781149999999997',
#   'rate_code': '2',
#   'tip_amount': '0',
#   'tolls_amount': '5.3300000000000001',
#   'total_amount': '57.829999999999998',
#   'trip_distance': '18.379999999999999',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-02-22T17:54:37.000',
#   'dropoff_latitude': '40.781844999999997',
#   'dropoff_longitude': '-73.979073',
#   'fare_amount': '7.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-02-22T17:47:23.000',
#   'pickup_latitude': '40.766931',
#   'pickup_longitude': '-73.982097999999993',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '8',
#   'trip_distance': '1.3',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-04-06T04:07:34.000',
#   'dropoff_latitude': '40.726610000000001',
#   'dropoff_longitude': '-73.995954999999995',
#   'fare_amount': '15.5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-04-06T03:51:59.000',
#   'pickup_latitude': '40.777729999999998',
#   'pickup_longitude': '-73.951902000000004',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '3.2999999999999998',
#   'tolls_amount': '0',
#   'total_amount': '19.800000000000001',
#   'trip_distance': '4.5',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-09-08T21:15:30.000',
#   'dropoff_latitude': '40.773372999999999',
#   'dropoff_longitude': '-73.949354',
#   'fare_amount': '11.5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-09-08T21:02:17.000',
#   'pickup_latitude': '40.795678000000002',
#   'pickup_longitude': '-73.971048999999994',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '12.5',
#   'trip_distance': '2.3999999999999999',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-11-13T11:55:00.000',
#   'dropoff_latitude': '40.752932000000001',
#   'dropoff_longitude': '-73.974688',
#   'fare_amount': '5.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '2',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-11-13T11:50:00.000',
#   'pickup_latitude': '40.762912',
#   'pickup_longitude': '-73.967782',
#   'rate_code': '1',
#   'tip_amount': '1.1000000000000001',
#   'tolls_amount': '0',
#   'total_amount': '7.0999999999999996',
#   'trip_distance': '0.83999999999999997',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-03-25T19:15:41.000',
#   'dropoff_latitude': '40.739657000000001',
#   'dropoff_longitude': '-73.996350000000007',
#   'fare_amount': '6',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-03-25T19:08:59.000',
#   'pickup_latitude': '40.731175999999998',
#   'pickup_longitude': '-73.991572000000005',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'Y',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '7.5',
#   'trip_distance': '0.80000000000000004',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-11-27T04:53:20.000',
#   'dropoff_latitude': '40.802211999999997',
#   'dropoff_longitude': '-73.961761999999993',
#   'fare_amount': '4',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-27T04:50:41.000',
#   'pickup_latitude': '40.800218999999998',
#   'pickup_longitude': '-73.968097999999998',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '5',
#   'trip_distance': '0.5',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-09-21T21:02:31.000',
#   'dropoff_latitude': '40.735433999999998',
#   'dropoff_longitude': '-73.977671000000001',
#   'fare_amount': '52',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '2',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-09-21T20:18:41.000',
#   'pickup_latitude': '40.648508999999997',
#   'pickup_longitude': '-73.783507999999998',
#   'rate_code': '2',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '8',
#   'tolls_amount': '5.3300000000000001',
#   'total_amount': '65.829999999999998',
#   'trip_distance': '17.300000000000001',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-02-10T17:26:00.000',
#   'dropoff_latitude': '40.727226999999999',
#   'dropoff_longitude': '-73.976853000000006',
#   'fare_amount': '4.5',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-02-10T17:23:00.000',
#   'pickup_latitude': '40.721896999999998',
#   'pickup_longitude': '-73.983492999999996',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '6',
#   'trip_distance': '0.63',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-09-30T23:32:03.000',
#   'dropoff_latitude': '40.820473999999997',
#   'dropoff_longitude': '-73.944074000000001',
#   'fare_amount': '11.5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-09-30T23:20:30.000',
#   'pickup_latitude': '40.791566000000003',
#   'pickup_longitude': '-73.972223999999997',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '3.1000000000000001',
#   'tolls_amount': '0',
#   'total_amount': '15.6',
#   'trip_distance': '2.7999999999999998',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-03-15T13:10:05.000',
#   'dropoff_latitude': '40.751105000000003',
#   'dropoff_longitude': '-73.972252999999995',
#   'fare_amount': '6.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-03-15T13:02:36.000',
#   'pickup_latitude': '40.744895999999997',
#   'pickup_longitude': '-73.978618999999995',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1.3999999999999999',
#   'tolls_amount': '0',
#   'total_amount': '8.4000000000000004',
#   'trip_distance': '0.59999999999999998',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-09-20T02:40:46.000',
#   'dropoff_latitude': '40.733991000000003',
#   'dropoff_longitude': '-73.854061999999999',
#   'fare_amount': '7',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-09-20T02:34:03.000',
#   'pickup_latitude': '40.721950999999997',
#   'pickup_longitude': '-73.844435000000004',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1.6000000000000001',
#   'tolls_amount': '0',
#   'total_amount': '9.5999999999999996',
#   'trip_distance': '1.1000000000000001',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2015-01-01T00:04:04.000',
#   'dropoff_latitude': '40.722155999999998',
#   'dropoff_longitude': '-73.957713999999996',
#   'fare_amount': '17',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-12-31T23:43:45.000',
#   'pickup_latitude': '40.732382000000001',
#   'pickup_longitude': '-74.001682000000002',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '2',
#   'tolls_amount': '0',
#   'total_amount': '20',
#   'trip_distance': '4.2000000000000002',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-09-15T12:55:37.000',
#   'dropoff_latitude': '40.773612999999997',
#   'dropoff_longitude': '-73.959654999999998',
#   'fare_amount': '4',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-09-15T12:52:52.000',
#   'pickup_latitude': '40.768338999999997',
#   'pickup_longitude': '-73.961478',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '4.5',
#   'trip_distance': '0.40000000000000002',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-10-07T10:02:49.000',
#   'dropoff_latitude': '40.769261',
#   'dropoff_longitude': '-73.963158000000007',
#   'fare_amount': '5.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-07T09:57:23.000',
#   'pickup_latitude': '40.775933000000002',
#   'pickup_longitude': '-73.962446',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1',
#   'tolls_amount': '0',
#   'total_amount': '7',
#   'trip_distance': '0.59999999999999998',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-07-19T07:08:16.000',
#   'dropoff_latitude': '40.770346000000004',
#   'dropoff_longitude': '-73.864903999999996',
#   'fare_amount': '29.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-07-19T06:45:15.000',
#   'pickup_latitude': '40.794829',
#   'pickup_longitude': '-73.971475999999996',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '5.3300000000000001',
#   'total_amount': '35.329999999999998',
#   'trip_distance': '9.8000000000000007',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-11-19T23:53:00.000',
#   'dropoff_latitude': '40.769190000000002',
#   'dropoff_longitude': '-73.955032000000003',
#   'fare_amount': '5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '2',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-19T23:50:00.000',
#   'pickup_latitude': '40.758647000000003',
#   'pickup_longitude': '-73.964877999999999',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '6',
#   'trip_distance': '1.05',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-10-31T09:36:00.000',
#   'dropoff_latitude': '40.720816999999997',
#   'dropoff_longitude': '-74.010176999999999',
#   'fare_amount': '5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-31T09:32:00.000',
#   'pickup_latitude': '40.713638000000003',
#   'pickup_longitude': '-74.011587000000006',
#   'rate_code': '1',
#   'tip_amount': '1',
#   'tolls_amount': '0',
#   'total_amount': '6.5',
#   'trip_distance': '0.73999999999999999',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-03-24T18:51:40.000',
#   'dropoff_latitude': '40.750017999999997',
#   'dropoff_longitude': '-73.986080000000001',
#   'fare_amount': '26',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '2',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-03-24T18:30:51.000',
#   'pickup_latitude': '40.774030000000003',
#   'pickup_longitude': '-73.874596999999994',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '8.1999999999999993',
#   'tolls_amount': '5.3300000000000001',
#   'total_amount': '41.030000000000001',
#   'trip_distance': '8.4000000000000004',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-04-09T23:55:17.000',
#   'dropoff_latitude': '40.780655000000003',
#   'dropoff_longitude': '-73.950056000000004',
#   'fare_amount': '21.5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '2',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-04-09T23:28:24.000',
#   'pickup_latitude': '40.728127000000001',
#   'pickup_longitude': '-73.998869999999997',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '3',
#   'tolls_amount': '0',
#   'total_amount': '25.5',
#   'trip_distance': '5.0999999999999996',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-03-06T16:12:01.000',
#   'dropoff_latitude': '40.777822999999998',
#   'dropoff_longitude': '-73.960832999999994',
#   'fare_amount': '7.5',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-03-06T16:04:23.000',
#   'pickup_latitude': '40.759670999999997',
#   'pickup_longitude': '-73.976687999999996',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1.8',
#   'tolls_amount': '0',
#   'total_amount': '10.800000000000001',
#   'trip_distance': '1.3999999999999999',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-12-23T15:37:25.000',
#   'dropoff_latitude': '40.744025000000001',
#   'dropoff_longitude': '-73.995136000000002',
#   'fare_amount': '18',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-12-23T15:09:38.000',
#   'pickup_latitude': '40.772651000000003',
#   'pickup_longitude': '-73.967095',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '4.5999999999999996',
#   'tolls_amount': '0',
#   'total_amount': '23.100000000000001',
#   'trip_distance': '2.7000000000000002',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-02-09T12:19:26.000',
#   'dropoff_latitude': '40.780225000000002',
#   'dropoff_longitude': '-73.955196000000001',
#   'fare_amount': '4.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-02-09T12:16:48.000',
#   'pickup_latitude': '40.770319000000001',
#   'pickup_longitude': '-73.960222000000002',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1',
#   'tolls_amount': '0',
#   'total_amount': '6',
#   'trip_distance': '0.80000000000000004',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-11-08T12:25:00.000',
#   'dropoff_latitude': '40.713932',
#   'dropoff_longitude': '-73.991834999999995',
#   'fare_amount': '7',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '5',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-08T12:14:00.000',
#   'pickup_latitude': '40.720457000000003',
#   'pickup_longitude': '-73.988065000000006',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '7.5',
#   'trip_distance': '1.1200000000000001',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-10-08T01:35:17.000',
#   'dropoff_latitude': '40.841256000000001',
#   'dropoff_longitude': '-73.783575999999996',
#   'fare_amount': '44',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-10-08T01:06:04.000',
#   'pickup_latitude': '40.754789000000002',
#   'pickup_longitude': '-73.973606000000004',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '45',
#   'trip_distance': '16',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-06-10T14:11:53.000',
#   'dropoff_latitude': '40.741031',
#   'dropoff_longitude': '-73.983575000000002',
#   'fare_amount': '8.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-06-10T14:01:05.000',
#   'pickup_latitude': '40.755654',
#   'pickup_longitude': '-73.985845999999995',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '9',
#   'trip_distance': '1.3999999999999999',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-04-29T18:24:50.000',
#   'dropoff_latitude': '40.746358999999998',
#   'dropoff_longitude': '-73.994101999999998',
#   'fare_amount': '7.5',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-04-29T18:15:44.000',
#   'pickup_latitude': '40.741568000000001',
#   'pickup_longitude': '-73.978341',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '9',
#   'trip_distance': '0.90000000000000002',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-10-27T17:18:00.000',
#   'dropoff_latitude': '40.737296999999998',
#   'dropoff_longitude': '-73.996296999999998',
#   'fare_amount': '6.5',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '5',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-10-27T17:10:00.000',
#   'pickup_latitude': '40.736907000000002',
#   'pickup_longitude': '-73.988619999999997',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '8',
#   'trip_distance': '0.73999999999999999',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-02-21T07:28:22.000',
#   'dropoff_latitude': '40.75479',
#   'dropoff_longitude': '-73.984453000000002',
#   'fare_amount': '8',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-02-21T07:19:24.000',
#   'pickup_latitude': '40.76003',
#   'pickup_longitude': '-73.964842000000004',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1.7',
#   'tolls_amount': '0',
#   'total_amount': '10.199999999999999',
#   'trip_distance': '1.5',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-03-06T14:52:54.000',
#   'dropoff_latitude': '40.729244999999999',
#   'dropoff_longitude': '-74.002258999999995',
#   'fare_amount': '5.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-03-06T14:47:54.000',
#   'pickup_latitude': '40.721366000000003',
#   'pickup_longitude': '-74.008286999999996',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1',
#   'tolls_amount': '0',
#   'total_amount': '7',
#   'trip_distance': '0.69999999999999996',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-05-11T23:16:00.000',
#   'dropoff_latitude': '40.756149999999998',
#   'dropoff_longitude': '-74.002656999999999',
#   'fare_amount': '10',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '5',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-05-11T23:04:00.000',
#   'pickup_latitude': '40.760147000000003',
#   'pickup_longitude': '-73.97627',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '11',
#   'trip_distance': '1.97',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-09-25T14:54:00.000',
#   'dropoff_latitude': '40.73659',
#   'dropoff_longitude': '-74.001142000000002',
#   'fare_amount': '6',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-09-25T14:47:00.000',
#   'pickup_latitude': '40.745846999999998',
#   'pickup_longitude': '-74.001817000000003',
#   'rate_code': '1',
#   'tip_amount': '1.2',
#   'tolls_amount': '0',
#   'total_amount': '7.7000000000000002',
#   'trip_distance': '0.95999999999999996',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-06-19T12:11:00.000',
#   'dropoff_latitude': '40.758865',
#   'dropoff_longitude': '-73.977012000000002',
#   'fare_amount': '6',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-06-19T12:04:00.000',
#   'pickup_latitude': '40.753014999999998',
#   'pickup_longitude': '-73.985247000000001',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '6.5',
#   'trip_distance': '0.73999999999999999',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-08-07T07:46:02.000',
#   'dropoff_latitude': '40.659523',
#   'dropoff_longitude': '-73.949675999999997',
#   'fare_amount': '42.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-08-07T07:00:25.000',
#   'pickup_latitude': '40.644657000000002',
#   'pickup_longitude': '-73.782229000000001',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '43',
#   'trip_distance': '12.699999999999999',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-02-06T16:23:00.000',
#   'dropoff_latitude': '40.738737',
#   'dropoff_longitude': '-73.992067000000006',
#   'fare_amount': '7.5',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-02-06T16:15:00.000',
#   'pickup_latitude': '40.738767000000003',
#   'pickup_longitude': '-74.008600000000001',
#   'rate_code': '1',
#   'tip_amount': '2.1200000000000001',
#   'tolls_amount': '0',
#   'total_amount': '11.119999999999999',
#   'trip_distance': '1.1699999999999999',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-08-19T13:17:54.000',
#   'dropoff_latitude': '40.771951999999999',
#   'dropoff_longitude': '-73.571903000000006',
#   'fare_amount': '87',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-08-19T12:39:47.000',
#   'pickup_latitude': '40.773797000000002',
#   'pickup_longitude': '-73.871065000000002',
#   'rate_code': '4',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '87.5',
#   'trip_distance': '22.800000000000001',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-04-16T13:33:05.000',
#   'dropoff_latitude': '40.734974999999999',
#   'dropoff_longitude': '-73.994439999999997',
#   'fare_amount': '9.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-04-16T13:21:14.000',
#   'pickup_latitude': '40.743411000000002',
#   'pickup_longitude': '-73.976860000000002',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '10',
#   'trip_distance': '1.5',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-09-26T18:07:48.000',
#   'dropoff_latitude': '40.741962000000001',
#   'dropoff_longitude': '-73.980779999999996',
#   'fare_amount': '10.5',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-09-26T17:53:16.000',
#   'pickup_latitude': '40.758904999999999',
#   'pickup_longitude': '-73.967896999999994',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '2.3999999999999999',
#   'tolls_amount': '0',
#   'total_amount': '14.4',
#   'trip_distance': '1.5',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-10-24T18:01:00.000',
#   'dropoff_latitude': '40.736396999999997',
#   'dropoff_longitude': '-74.008317000000005',
#   'fare_amount': '11',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-24T17:46:00.000',
#   'pickup_latitude': '40.733877',
#   'pickup_longitude': '-73.989602000000005',
#   'rate_code': '1',
#   'tip_amount': '2.3999999999999999',
#   'tolls_amount': '0',
#   'total_amount': '14.9',
#   'trip_distance': '1.7',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-01-08T20:48:00.000',
#   'dropoff_latitude': '40.714649999999999',
#   'dropoff_longitude': '-73.991079999999997',
#   'fare_amount': '6.5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-01-08T20:40:00.000',
#   'pickup_latitude': '40.726162000000002',
#   'pickup_longitude': '-73.983431999999993',
#   'rate_code': '1',
#   'tip_amount': '1',
#   'tolls_amount': '0',
#   'total_amount': '8.5',
#   'trip_distance': '0.94999999999999996',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-10-18T13:53:00.000',
#   'dropoff_latitude': '40.72627',
#   'dropoff_longitude': '-73.999297999999996',
#   'fare_amount': '20',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '5',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-18T13:36:00.000',
#   'pickup_latitude': '40.775122000000003',
#   'pickup_longitude': '-73.947765000000004',
#   'rate_code': '1',
#   'tip_amount': '1.5',
#   'tolls_amount': '0',
#   'total_amount': '22',
#   'trip_distance': '5.8799999999999999',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-05-29T23:54:16.000',
#   'dropoff_latitude': '40.758560000000003',
#   'dropoff_longitude': '-73.916076000000004',
#   'fare_amount': '16.5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-05-29T23:35:59.000',
#   'pickup_latitude': '40.759869999999999',
#   'pickup_longitude': '-73.978487000000001',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '3.5',
#   'tolls_amount': '0',
#   'total_amount': '21',
#   'trip_distance': '4.0999999999999996',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-03-11T18:36:00.000',
#   'dropoff_latitude': '40.721972000000001',
#   'dropoff_longitude': '-73.947226999999998',
#   'fare_amount': '6',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '5',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-03-11T18:30:00.000',
#   'pickup_latitude': '40.707087000000001',
#   'pickup_longitude': '-73.943280000000001',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '7.5',
#   'trip_distance': '1.0900000000000001',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-04-04T19:24:00.000',
#   'dropoff_latitude': '40.728095000000003',
#   'dropoff_longitude': '-73.994569999999996',
#   'fare_amount': '7.5',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '2',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-04-04T19:14:00.000',
#   'pickup_latitude': '40.741911999999999',
#   'pickup_longitude': '-74.003578000000005',
#   'rate_code': '1',
#   'tip_amount': '2.1200000000000001',
#   'tolls_amount': '0',
#   'total_amount': '11.119999999999999',
#   'trip_distance': '1.3899999999999999',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-05-25T17:41:05.000',
#   'dropoff_latitude': '40.697947999999997',
#   'dropoff_longitude': '-73.995543999999995',
#   'fare_amount': '31.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '2',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-05-25T17:16:12.000',
#   'pickup_latitude': '40.769112',
#   'pickup_longitude': '-73.862679',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '8',
#   'tolls_amount': '0',
#   'total_amount': '40',
#   'trip_distance': '11.199999999999999',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-02-27T22:33:00.000',
#   'dropoff_latitude': '40.762002000000003',
#   'dropoff_longitude': '-73.985797000000005',
#   'fare_amount': '10.5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '2',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-02-27T22:22:00.000',
#   'pickup_latitude': '40.785806999999998',
#   'pickup_longitude': '-73.976387000000003',
#   'rate_code': '1',
#   'tip_amount': '2.2000000000000002',
#   'tolls_amount': '0',
#   'total_amount': '13.699999999999999',
#   'trip_distance': '2.5600000000000001',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-04-07T20:28:00.000',
#   'dropoff_latitude': '40.756317000000003',
#   'dropoff_longitude': '-73.974879999999999',
#   'fare_amount': '6',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-04-07T20:22:00.000',
#   'pickup_latitude': '40.751300000000001',
#   'pickup_longitude': '-73.986851999999999',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '7',
#   'trip_distance': '1.03',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-12-12T14:22:00.000',
#   'dropoff_latitude': '40.749845000000001',
#   'dropoff_longitude': '-73.975105999999997',
#   'fare_amount': '11.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-12-12T14:04:53.000',
#   'pickup_latitude': '40.733384999999998',
#   'pickup_longitude': '-73.987204000000006',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1',
#   'tolls_amount': '0',
#   'total_amount': '13',
#   'trip_distance': '1.3',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-06-30T16:58:59.000',
#   'dropoff_latitude': '40.748457000000002',
#   'dropoff_longitude': '-73.984583999999998',
#   'fare_amount': '5.5',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-06-30T16:54:27.000',
#   'pickup_latitude': '40.760257000000003',
#   'pickup_longitude': '-73.976185999999998',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1.3999999999999999',
#   'tolls_amount': '0',
#   'total_amount': '8.4000000000000004',
#   'trip_distance': '0.90000000000000002',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-12-14T00:38:43.000',
#   'dropoff_latitude': '40.777341',
#   'dropoff_longitude': '-73.982516000000004',
#   'fare_amount': '17',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'NOC',
#   'pickup_datetime': '2014-12-14T00:15:19.000',
#   'pickup_latitude': '40.741249000000003',
#   'pickup_longitude': '-74.005201',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '18',
#   'trip_distance': '3.3999999999999999',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-06-16T21:10:34.000',
#   'dropoff_latitude': '40.760930000000002',
#   'dropoff_longitude': '-73.998472000000007',
#   'fare_amount': '5.5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-06-16T21:05:13.000',
#   'pickup_latitude': '40.759794999999997',
#   'pickup_longitude': '-73.985352000000006',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1.3',
#   'tolls_amount': '0',
#   'total_amount': '7.7999999999999998',
#   'trip_distance': '0.80000000000000004',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-10-11T19:09:07.000',
#   'dropoff_latitude': '40.751592000000002',
#   'dropoff_longitude': '-73.976827',
#   'fare_amount': '6.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-11T19:01:32.000',
#   'pickup_latitude': '40.756636',
#   'pickup_longitude': '-73.969700000000003',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '2.1000000000000001',
#   'tolls_amount': '0',
#   'total_amount': '9.0999999999999996',
#   'trip_distance': '0.80000000000000004',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-11-11T16:14:08.000',
#   'dropoff_latitude': '40.744498',
#   'dropoff_longitude': '-74.007935000000003',
#   'fare_amount': '5.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-11-11T16:08:26.000',
#   'pickup_latitude': '40.739249999999998',
#   'pickup_longitude': '-74.000759000000002',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1.2',
#   'tolls_amount': '0',
#   'total_amount': '7.2000000000000002',
#   'trip_distance': '0.59999999999999998',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-02-08T02:00:00.000',
#   'dropoff_latitude': '40.747731999999999',
#   'dropoff_longitude': '-73.989097000000001',
#   'fare_amount': '6.5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-02-08T01:53:00.000',
#   'pickup_latitude': '40.751055000000001',
#   'pickup_longitude': '-73.976070000000007',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '7.5',
#   'trip_distance': '1.0700000000000001',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-03-15T19:20:03.000',
#   'dropoff_latitude': '40.683391999999998',
#   'dropoff_longitude': '-73.999790000000004',
#   'fare_amount': '17.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-03-15T18:57:37.000',
#   'pickup_latitude': '40.723584000000002',
#   'pickup_longitude': '-73.995992000000001',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '18',
#   'trip_distance': '3.8999999999999999',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-05-25T07:02:00.000',
#   'dropoff_latitude': '40.644306999999998',
#   'dropoff_longitude': '-73.790767000000002',
#   'fare_amount': '39',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-05-25T06:43:00.000',
#   'pickup_latitude': '40.757036999999997',
#   'pickup_longitude': '-73.929485',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '39.5',
#   'trip_distance': '14.43',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-11-18T08:30:40.000',
#   'dropoff_latitude': '40.750042999999998',
#   'dropoff_longitude': '-73.979163',
#   'fare_amount': '5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-18T08:25:55.000',
#   'pickup_latitude': '40.743385000000004',
#   'pickup_longitude': '-73.981977999999998',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '5.5',
#   'trip_distance': '0.59999999999999998',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-10-04T15:31:57.000',
#   'dropoff_latitude': '40.761550999999997',
#   'dropoff_longitude': '-73.970070000000007',
#   'fare_amount': '8.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-10-04T15:23:55.000',
#   'pickup_latitude': '40.737485999999997',
#   'pickup_longitude': '-73.978153000000006',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '9',
#   'trip_distance': '2.1000000000000001',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-10-26T13:16:00.000',
#   'dropoff_latitude': '40.763030000000001',
#   'dropoff_longitude': '-73.973770000000002',
#   'fare_amount': '8.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-26T13:08:00.000',
#   'pickup_latitude': '40.77225',
#   'pickup_longitude': '-73.952849999999998',
#   'rate_code': '1',
#   'tip_amount': '2.1200000000000001',
#   'tolls_amount': '0',
#   'total_amount': '11.119999999999999',
#   'trip_distance': '1.76',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-07-01T18:39:00.000',
#   'dropoff_latitude': '40.706077000000001',
#   'dropoff_longitude': '-74.006856999999997',
#   'fare_amount': '11',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-07-01T18:27:00.000',
#   'pickup_latitude': '40.732881999999996',
#   'pickup_longitude': '-73.981975000000006',
#   'rate_code': '1',
#   'tip_amount': '2.3999999999999999',
#   'tolls_amount': '0',
#   'total_amount': '14.9',
#   'trip_distance': '2.4500000000000002',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-10-06T19:18:00.000',
#   'dropoff_latitude': '40.799965',
#   'dropoff_longitude': '-73.969547000000006',
#   'fare_amount': '8.5',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-06T19:10:00.000',
#   'pickup_latitude': '40.774566999999998',
#   'pickup_longitude': '-73.988231999999996',
#   'rate_code': '1',
#   'tip_amount': '2.3799999999999999',
#   'tolls_amount': '0',
#   'total_amount': '12.380000000000001',
#   'trip_distance': '2.0299999999999998',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-08-11T17:57:00.000',
#   'dropoff_latitude': '40.753734999999999',
#   'dropoff_longitude': '-73.974355000000003',
#   'fare_amount': '6.5',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '5',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-08-11T17:49:00.000',
#   'pickup_latitude': '40.757437000000003',
#   'pickup_longitude': '-73.964735000000005',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '8',
#   'trip_distance': '0.80000000000000004',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-02-09T13:03:00.000',
#   'dropoff_latitude': '40.796771999999997',
#   'dropoff_longitude': '-73.948921999999996',
#   'fare_amount': '10',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '5',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-02-09T12:52:00.000',
#   'pickup_latitude': '40.789636999999999',
#   'pickup_longitude': '-73.975402000000003',
#   'rate_code': '1',
#   'tip_amount': '2',
#   'tolls_amount': '0',
#   'total_amount': '12.5',
#   'trip_distance': '2.1400000000000001',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-02-26T11:36:37.000',
#   'dropoff_latitude': '40.740513',
#   'dropoff_longitude': '-73.992580000000004',
#   'fare_amount': '10',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-02-26T11:22:53.000',
#   'pickup_latitude': '40.754317',
#   'pickup_longitude': '-73.992547999999999',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '2.1000000000000001',
#   'tolls_amount': '0',
#   'total_amount': '12.6',
#   'trip_distance': '1.3',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-02-14T11:00:00.000',
#   'dropoff_latitude': '40.750145000000003',
#   'dropoff_longitude': '-73.994910000000004',
#   'fare_amount': '6.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '2',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-02-14T10:52:00.000',
#   'pickup_latitude': '40.745007000000001',
#   'pickup_longitude': '-73.998626999999999',
#   'rate_code': '1',
#   'tip_amount': '1.3',
#   'tolls_amount': '0',
#   'total_amount': '8.3000000000000007',
#   'trip_distance': '0.44',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-12-19T21:10:00.000',
#   'dropoff_latitude': '40.727539999999998',
#   'dropoff_longitude': '-73.982410000000002',
#   'fare_amount': '7',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '2',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-12-19T21:02:00.000',
#   'pickup_latitude': '40.734982000000002',
#   'pickup_longitude': '-73.990522999999996',
#   'rate_code': '1',
#   'tip_amount': '1.5',
#   'tolls_amount': '0',
#   'total_amount': '9.5',
#   'trip_distance': '1',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-08-03T13:48:00.000',
#   'dropoff_latitude': '0',
#   'dropoff_longitude': '0',
#   'fare_amount': '10',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-08-03T13:35:00.000',
#   'pickup_latitude': '0',
#   'pickup_longitude': '0',
#   'rate_code': '1',
#   'tip_amount': '2.5',
#   'tolls_amount': '0',
#   'total_amount': '13',
#   'trip_distance': '1.95',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-05-26T12:55:00.000',
#   'dropoff_latitude': '40.751156999999999',
#   'dropoff_longitude': '-73.991399999999999',
#   'fare_amount': '8.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-05-26T12:46:00.000',
#   'pickup_latitude': '40.738616999999998',
#   'pickup_longitude': '-73.989671999999999',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '9',
#   'trip_distance': '1.48',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-02-25T20:20:24.000',
#   'dropoff_latitude': '40.797089999999997',
#   'dropoff_longitude': '-73.968839000000003',
#   'fare_amount': '3.5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-02-25T20:19:07.000',
#   'pickup_latitude': '40.790711999999999',
#   'pickup_longitude': '-73.972808999999998',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '4.5',
#   'trip_distance': '0.5',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-08-09T11:58:30.000',
#   'dropoff_latitude': '40.763725999999998',
#   'dropoff_longitude': '-73.971545000000006',
#   'fare_amount': '7.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-08-09T11:51:20.000',
#   'pickup_latitude': '40.750166999999998',
#   'pickup_longitude': '-73.987397999999999',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '8',
#   'trip_distance': '1.5',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-07-24T14:08:04.000',
#   'dropoff_latitude': '40.597785000000002',
#   'dropoff_longitude': '-73.966444999999993',
#   'fare_amount': '38.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '2',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-07-24T13:34:18.000',
#   'pickup_latitude': '40.732140999999999',
#   'pickup_longitude': '-73.984470000000002',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '39',
#   'trip_distance': '12.699999999999999',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-03-13T15:01:59.000',
#   'dropoff_latitude': '40.75168',
#   'dropoff_longitude': '-74.005762000000004',
#   'fare_amount': '5.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '2',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-03-13T14:57:46.000',
#   'pickup_latitude': '40.765757999999998',
#   'pickup_longitude': '-73.994846999999993',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1.2',
#   'tolls_amount': '0',
#   'total_amount': '7.2000000000000002',
#   'trip_distance': '1.1000000000000001',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-05-11T16:56:25.000',
#   'dropoff_latitude': '40.785750999999998',
#   'dropoff_longitude': '-73.976721999999995',
#   'fare_amount': '6',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '4',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-05-11T16:50:24.000',
#   'pickup_latitude': '40.792594000000001',
#   'pickup_longitude': '-73.964101999999997',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '2',
#   'tolls_amount': '0',
#   'total_amount': '8.5',
#   'trip_distance': '1',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-03-27T20:25:44.000',
#   'dropoff_latitude': '40.749738000000001',
#   'dropoff_longitude': '-73.987525000000005',
#   'fare_amount': '9',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-03-27T20:15:58.000',
#   'pickup_latitude': '40.762908000000003',
#   'pickup_longitude': '-73.969549000000001',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '10',
#   'trip_distance': '1.8',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-08-15T16:36:00.000',
#   'dropoff_latitude': '40.803004999999999',
#   'dropoff_longitude': '-73.963774999999998',
#   'fare_amount': '20',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-08-15T16:09:00.000',
#   'pickup_latitude': '40.750722000000003',
#   'pickup_longitude': '-73.968446999999998',
#   'rate_code': '1',
#   'tip_amount': '4.2000000000000002',
#   'tolls_amount': '0',
#   'total_amount': '25.699999999999999',
#   'trip_distance': '4.8499999999999996',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-11-16T18:43:00.000',
#   'dropoff_latitude': '40.722627000000003',
#   'dropoff_longitude': '-73.840562000000006',
#   'fare_amount': '16.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '5',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-16T18:30:00.000',
#   'pickup_latitude': '40.769886999999997',
#   'pickup_longitude': '-73.864429999999999',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '17',
#   'trip_distance': '5.0899999999999999',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-03-13T02:50:55.000',
#   'dropoff_latitude': '40.781950999999999',
#   'dropoff_longitude': '-73.979130999999995',
#   'fare_amount': '6',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-03-13T02:47:01.000',
#   'pickup_latitude': '40.772469999999998',
#   'pickup_longitude': '-73.982418999999993',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '7',
#   'trip_distance': '1.2',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-06-27T03:08:00.000',
#   'dropoff_latitude': '40.776617000000002',
#   'dropoff_longitude': '-73.989395000000002',
#   'fare_amount': '7.5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '6',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-06-27T03:01:00.000',
#   'pickup_latitude': '40.764544999999998',
#   'pickup_longitude': '-73.982668000000004',
#   'rate_code': '1',
#   'tip_amount': '1.6000000000000001',
#   'tolls_amount': '0',
#   'total_amount': '10.1',
#   'trip_distance': '1.4399999999999999',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-11-18T13:02:00.000',
#   'dropoff_latitude': '40.750025000000001',
#   'dropoff_longitude': '-73.978202999999993',
#   'fare_amount': '52',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '2',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-11-18T12:11:00.000',
#   'pickup_latitude': '40.641804999999998',
#   'pickup_longitude': '-73.786410000000004',
#   'rate_code': '2',
#   'tip_amount': '11.470000000000001',
#   'tolls_amount': '5.3300000000000001',
#   'total_amount': '69.299999999999997',
#   'trip_distance': '16.629999999999999',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-07-01T10:46:00.000',
#   'dropoff_latitude': '40.752116999999998',
#   'dropoff_longitude': '-73.986840000000001',
#   'fare_amount': '5.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-07-01T10:40:00.000',
#   'pickup_latitude': '40.75224',
#   'pickup_longitude': '-73.978350000000006',
#   'rate_code': '1',
#   'tip_amount': '1.1000000000000001',
#   'tolls_amount': '0',
#   'total_amount': '7.0999999999999996',
#   'trip_distance': '0.79000000000000004',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-04-26T17:06:00.000',
#   'dropoff_latitude': '40.750149999999998',
#   'dropoff_longitude': '-73.994874999999993',
#   'fare_amount': '11',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-04-26T16:50:00.000',
#   'pickup_latitude': '40.758834999999998',
#   'pickup_longitude': '-73.988555000000005',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '11.5',
#   'trip_distance': '1.3600000000000001',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-05-23T07:49:00.000',
#   'dropoff_latitude': '40.746622000000002',
#   'dropoff_longitude': '-73.971384999999998',
#   'fare_amount': '8',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '5',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-05-23T07:43:00.000',
#   'pickup_latitude': '40.722785000000002',
#   'pickup_longitude': '-73.988557999999998',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '8.5',
#   'trip_distance': '2.04',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-04-24T19:44:06.000',
#   'dropoff_latitude': '40.732010000000002',
#   'dropoff_longitude': '-73.993964000000005',
#   'fare_amount': '6.5',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-04-24T19:36:48.000',
#   'pickup_latitude': '40.720337999999998',
#   'pickup_longitude': '-73.993645000000001',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '2',
#   'tolls_amount': '0',
#   'total_amount': '10',
#   'trip_distance': '0.90000000000000002',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-05-27T21:24:00.000',
#   'dropoff_latitude': '40.744886999999999',
#   'dropoff_longitude': '-74.001519999999999',
#   'fare_amount': '8',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '6',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-05-27T21:15:00.000',
#   'pickup_latitude': '40.729730000000004',
#   'pickup_longitude': '-73.991628000000006',
#   'rate_code': '1',
#   'tip_amount': '1.7',
#   'tolls_amount': '0',
#   'total_amount': '10.699999999999999',
#   'trip_distance': '1.6499999999999999',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-08-02T10:55:00.000',
#   'dropoff_latitude': '40.760461999999997',
#   'dropoff_longitude': '-73.967141999999996',
#   'fare_amount': '6',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '3',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-08-02T10:49:00.000',
#   'pickup_latitude': '40.760441999999998',
#   'pickup_longitude': '-73.958404999999999',
#   'rate_code': '1',
#   'tip_amount': '1',
#   'tolls_amount': '0',
#   'total_amount': '7.5',
#   'trip_distance': '0.64000000000000001',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-05-12T14:43:00.000',
# ...
#   'pickup_latitude': '40.749760000000002',
#   'pickup_longitude': '-73.993847000000002',
#   'rate_code': '1',
#   'tip_amount': '3.2999999999999998',
#   'tolls_amount': '0',
#   'total_amount': '14.800000000000001',
#   'trip_distance': '1.0800000000000001',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-10-05T13:42:06.000',
#   'dropoff_latitude': '40.745455',
#   'dropoff_longitude': '-73.990701999999999',
#   'fare_amount': '9',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-05T13:31:38.000',
#   'pickup_latitude': '40.753168000000002',
#   'pickup_longitude': '-73.969728000000003',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1.6000000000000001',
#   'tolls_amount': '0',
#   'total_amount': '11.1',
#   'trip_distance': '1.7',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-01-13T19:36:42.000',
#   'dropoff_latitude': '40.753664000000001',
#   'dropoff_longitude': '-73.977404000000007',
#   'fare_amount': '5.5',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '2',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-01-13T19:31:58.000',
#   'pickup_latitude': '40.764099000000002',
#   'pickup_longitude': '-73.973033000000001',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '7',
#   'trip_distance': '0.80000000000000004',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-09-21T01:25:00.000',
#   'dropoff_latitude': '40.719546999999999',
#   'dropoff_longitude': '-74.006157000000002',
#   'fare_amount': '24',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '5',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-09-21T00:59:00.000',
#   'pickup_latitude': '40.796756999999999',
#   'pickup_longitude': '-73.970536999999993',
#   'rate_code': '1',
#   'tip_amount': '4.9000000000000004',
#   'tolls_amount': '0',
#   'total_amount': '29.899999999999999',
#   'trip_distance': '6.7999999999999998',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-11-06T11:02:51.000',
#   'dropoff_latitude': '40.752281000000004',
#   'dropoff_longitude': '-73.981836000000001',
#   'fare_amount': '10',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-06T10:48:01.000',
#   'pickup_latitude': '40.765014999999998',
#   'pickup_longitude': '-73.976836000000006',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '10.5',
#   'trip_distance': '1.1000000000000001',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-05-06T21:30:25.000',
#   'dropoff_latitude': '40.727946000000003',
#   'dropoff_longitude': '-73.982433999999998',
#   'fare_amount': '4',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-05-06T21:28:13.000',
#   'pickup_latitude': '40.722397000000001',
#   'pickup_longitude': '-73.988933000000003',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1',
#   'tolls_amount': '0',
#   'total_amount': '6',
#   'trip_distance': '0.59999999999999998',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-11-13T16:26:00.000',
#   'dropoff_latitude': '40.768987000000003',
#   'dropoff_longitude': '-73.958352000000005',
#   'fare_amount': '9',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-13T16:15:00.000',
#   'pickup_latitude': '40.784722000000002',
#   'pickup_longitude': '-73.958017999999996',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '10.5',
#   'trip_distance': '1.48',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-08-04T00:25:00.000',
#   'dropoff_latitude': '40.748151999999997',
#   'dropoff_longitude': '-73.984909999999999',
#   'fare_amount': '9',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-08-04T00:16:00.000',
#   'pickup_latitude': '40.734082000000001',
#   'pickup_longitude': '-74.006202000000002',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '10',
#   'trip_distance': '2.0299999999999998',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-04-13T21:10:00.000',
#   'dropoff_latitude': '40.75',
#   'dropoff_longitude': '-73.99145',
#   'fare_amount': '5.5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-04-13T21:04:00.000',
#   'pickup_latitude': '40.747720000000001',
#   'pickup_longitude': '-73.982740000000007',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '6.5',
#   'trip_distance': '0.56000000000000005',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-04-15T13:40:34.000',
#   'dropoff_latitude': '40.753573000000003',
#   'dropoff_longitude': '-73.989866000000006',
#   'fare_amount': '13',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-04-15T13:21:38.000',
#   'pickup_latitude': '40.774329000000002',
#   'pickup_longitude': '-73.988896999999994',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1',
#   'tolls_amount': '0',
#   'total_amount': '14.5',
#   'trip_distance': '2.2999999999999998',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-01-15T23:17:07.000',
#   'dropoff_latitude': '40.748479000000003',
#   'dropoff_longitude': '-73.996055999999996',
#   'fare_amount': '5.5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-01-15T23:11:51.000',
#   'pickup_latitude': '40.742365999999997',
#   'pickup_longitude': '-73.993170000000006',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '6.5',
#   'trip_distance': '0.59999999999999998',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-06-01T03:00:14.000',
#   'dropoff_latitude': '40.73659',
#   'dropoff_longitude': '-73.990836999999999',
#   'fare_amount': '5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '4',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-06-01T02:55:51.000',
#   'pickup_latitude': '40.739342000000001',
#   'pickup_longitude': '-74.001677000000001',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '6',
#   'trip_distance': '0.69999999999999996',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-10-08T21:16:59.000',
#   'dropoff_latitude': '40.745750000000001',
#   'dropoff_longitude': '-74.001947000000001',
#   'fare_amount': '7',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-10-08T21:10:35.000',
#   'pickup_latitude': '40.756363',
#   'pickup_longitude': '-73.985772999999995',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '8',
#   'trip_distance': '1.3999999999999999',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-04-17T19:29:36.000',
#   'dropoff_latitude': '40.780430000000003',
#   'dropoff_longitude': '-73.946700000000007',
#   'fare_amount': '13.5',
#   'imp_surcharge': '1',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-04-17T19:15:43.000',
#   'pickup_latitude': '40.738253999999998',
#   'pickup_longitude': '-73.983498999999995',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '4.5',
#   'tolls_amount': '0',
#   'total_amount': '19.5',
#   'trip_distance': '3.7999999999999998',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-01-11T16:54:00.000',
#   'dropoff_latitude': '40.749512000000003',
#   'dropoff_longitude': '-73.981654000000006',
#   'fare_amount': '7.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-01-11T16:45:10.000',
#   'pickup_latitude': '40.735045999999997',
#   'pickup_longitude': '-73.990119000000007',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1.6000000000000001',
#   'tolls_amount': '0',
#   'total_amount': '9.5999999999999996',
#   'trip_distance': '1.1000000000000001',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-06-28T22:59:37.000',
#   'dropoff_latitude': '40.722290000000001',
#   'dropoff_longitude': '-73.996426999999997',
#   'fare_amount': '14',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-06-28T22:41:18.000',
#   'pickup_latitude': '40.755856999999999',
#   'pickup_longitude': '-73.997045',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '15',
#   'trip_distance': '3.1000000000000001',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-05-28T08:07:00.000',
#   'dropoff_latitude': '40.763652',
#   'dropoff_longitude': '-73.969645',
#   'fare_amount': '5.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '4',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-05-28T08:02:00.000',
#   'pickup_latitude': '40.772357',
#   'pickup_longitude': '-73.960926999999998',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '6',
#   'trip_distance': '0.88',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-07-15T05:20:00.000',
#   'dropoff_latitude': '40.790165000000002',
#   'dropoff_longitude': '-73.954269999999994',
#   'fare_amount': '8',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-07-15T05:11:00.000',
#   'pickup_latitude': '40.775272000000001',
#   'pickup_longitude': '-73.950429999999997',
#   'rate_code': '1',
#   'tip_amount': '1.7',
#   'tolls_amount': '0',
#   'total_amount': '10.699999999999999',
#   'trip_distance': '1.78',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-11-14T04:27:00.000',
#   'dropoff_latitude': '40.851714999999999',
#   'dropoff_longitude': '-73.933571999999998',
#   'fare_amount': '23',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-11-14T04:11:00.000',
#   'pickup_latitude': '40.763641999999997',
#   'pickup_longitude': '-73.988995000000003',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '24',
#   'trip_distance': '7.6799999999999997',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-09-21T17:29:00.000',
#   'dropoff_latitude': '40.760942',
#   'dropoff_longitude': '-73.986536999999998',
#   'fare_amount': '47.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '3',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-09-21T16:29:00.000',
#   'pickup_latitude': '40.768787000000003',
#   'pickup_longitude': '-73.862844999999993',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '48',
#   'trip_distance': '12.15',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-07-19T14:34:00.000',
#   'dropoff_latitude': '40.764330000000001',
#   'dropoff_longitude': '-73.957509999999999',
#   'fare_amount': '6',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-07-19T14:28:00.000',
#   'pickup_latitude': '40.772326999999997',
#   'pickup_longitude': '-73.952635000000001',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '6.5',
#   'trip_distance': '0.82999999999999996',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-03-26T22:09:30.000',
#   'dropoff_latitude': '40.766392000000003',
#   'dropoff_longitude': '-73.958485999999994',
#   'fare_amount': '7.5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-03-26T22:03:02.000',
#   'pickup_latitude': '40.750616999999998',
#   'pickup_longitude': '-73.973910000000004',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1',
#   'tolls_amount': '0',
#   'total_amount': '9.5',
#   'trip_distance': '1.6000000000000001',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-12-13T03:53:00.000',
#   'dropoff_latitude': '40.770676999999999',
#   'dropoff_longitude': '-73.958659999999995',
#   'fare_amount': '16.5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '5',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-12-13T03:34:00.000',
#   'pickup_latitude': '40.740490000000001',
#   'pickup_longitude': '-73.998152000000005',
#   'rate_code': '1',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '17.5',
#   'trip_distance': '4.2000000000000002',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-08-12T15:41:53.000',
#   'dropoff_latitude': '40.748296000000003',
#   'dropoff_longitude': '-73.983405000000005',
#   'fare_amount': '11.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-08-12T15:23:57.000',
#   'pickup_latitude': '40.759067000000002',
#   'pickup_longitude': '-73.977368999999996',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '2.3999999999999999',
#   'tolls_amount': '0',
#   'total_amount': '14.4',
#   'trip_distance': '1.1000000000000001',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-06-01T17:42:30.000',
#   'dropoff_latitude': '40.762765999999999',
#   'dropoff_longitude': '-73.988883999999999',
#   'fare_amount': '6',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '3',
#   'payment_type': 'CSH',
#   'pickup_datetime': '2014-06-01T17:36:21.000',
#   'pickup_latitude': '40.762444000000002',
#   'pickup_longitude': '-73.982439999999997',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '0',
#   'tolls_amount': '0',
#   'total_amount': '6.5',
#   'trip_distance': '0.80000000000000004',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-06-08T20:59:00.000',
#   'dropoff_latitude': '40.759054999999996',
#   'dropoff_longitude': '-73.987381999999997',
#   'fare_amount': '27.5',
#   'imp_surcharge': '0.5',
#   'mta_tax': '0.5',
#   'passenger_count': '5',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-06-08T20:36:00.000',
#   'pickup_latitude': '40.774087000000002',
#   'pickup_longitude': '-73.874592000000007',
#   'rate_code': '1',
#   'tip_amount': '4',
#   'tolls_amount': '5.3300000000000001',
#   'total_amount': '37.829999999999998',
#   'trip_distance': '9.25',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-01-25T16:30:36.000',
#   'dropoff_latitude': '40.775283999999999',
#   'dropoff_longitude': '-73.982410000000002',
#   'fare_amount': '4.5',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-01-25T16:26:06.000',
#   'pickup_latitude': '40.781736000000002',
#   'pickup_longitude': '-73.981283000000005',
#   'rate_code': '1',
#   'store_and_fwd_flag': 'N',
#   'tip_amount': '1',
#   'tolls_amount': '0',
#   'total_amount': '6',
#   'trip_distance': '0.40000000000000002',
#   'vendor_id': 'CMT'},
#  {'dropoff_datetime': '2014-10-14T11:47:00.000',
#   'dropoff_latitude': '40.748646999999998',
#   'dropoff_longitude': '-73.985006999999996',
#   'fare_amount': '10',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-10-14T11:33:00.000',
#   'pickup_latitude': '40.757812000000001',
#   'pickup_longitude': '-73.989041999999998',
#   'rate_code': '1',
#   'tip_amount': '2',
#   'tolls_amount': '0',
#   'total_amount': '12.5',
#   'trip_distance': '1.46',
#   'vendor_id': 'VTS'},
#  {'dropoff_datetime': '2014-05-27T06:35:00.000',
#   'dropoff_latitude': '40.781432000000002',
#   'dropoff_longitude': '-73.979457999999994',
#   'fare_amount': '4',
#   'imp_surcharge': '0',
#   'mta_tax': '0.5',
#   'passenger_count': '1',
#   'payment_type': 'CRD',
#   'pickup_datetime': '2014-05-27T06:32:00.000',
#   'pickup_latitude': '40.787171999999998',
#   'pickup_longitude': '-73.977630000000005',
#   'rate_code': '1',
#   'tip_amount': '1',
#   'tolls_amount': '0',
#   'total_amount': '5.5',
#   'trip_distance': '0.53000000000000003',
#   'vendor_id': 'VTS'}]

# %% [markdown]
# > Press shift + enter

# %% [markdown]
# #### Explore the data

# %% [markdown]
# The next step is to explore the data.  First, let's see how many trips we have.

# %%
len(trips)
# Out:
# 1000

# %% [markdown]
# Not bad at all.  Now let's see what each individual trip looks like.  Each trip is a dictionary, so we can see the attributes of each trip with the `keys` function.

# %%
trips[0].keys()
# Out:
# dict_keys(['dropoff_datetime', 'dropoff_latitude', 'dropoff_longitude', 'fare_amount', 'imp_surcharge', 'mta_tax', 'passenger_count', 'payment_type', 'pickup_datetime', 'pickup_latitude', 'pickup_longitude', 'rate_code', 'tip_amount', 'tolls_amount', 'total_amount', 'trip_distance', 'vendor_id'])

# %% [markdown]
# #### Limit our data

# %% [markdown]
# Ok, now that we have explored some of our data, let's begin to think through what data is relevant for our task.

# %% [markdown]
# Remember that our task is to **use the trip location to predict the length of a trip**.  So let's select the `pickup_latitude`, `pickup_longitude`, and `trip_distance` from each trip.  That will give us the trip location and related `trip_distance` for each trip.  Then based on these **actual** trip distances we can use nearest neighbors to predict an **expected** trip distance for a trip, provided an **actual** location.

# %% [markdown]
# ** Add in about trip distance **

# %% [markdown]
# Write a function called `parse_trips(trips)` that returns a list of the trips with only the following attributes:
# * `trip_distance`
# * `pickup_latitude`
# * `pickup_longitude`

# %%
def parse_trips(trips):
    return [{k: dict[k] for k in ('trip_distance', 'pickup_latitude', 'pickup_longitude')} for dict in trips]

# %%
parsed_trips = parse_trips(trips)
parsed_trips and parsed_trips[0]

# {'pickup_latitude': '40.64499',
#  'pickup_longitude': '-73.78115',
#  'trip_distance': '18.38'}
# Out:
# {'trip_distance': '18.379999999999999',
#  'pickup_latitude': '40.64499',
#  'pickup_longitude': '-73.781149999999997'}

# %% [markdown]
# Now, there's just one change to make.  If you look at one of the trips, all of the values are strings.  Let's change them to be floats.

# %%
def float_values(trips):    
    return [dict([key, float(value)] for key, value in dicts.items()) for dicts in trips]

# %%
cleaned_trips = float_values(parsed_trips)

# %%
cleaned_trips[0]

# {'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115,
#  'trip_distance': 18.38}
# Out:
# {'trip_distance': 18.38,
#  'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115}

# %% [markdown]
# ### Exploring the Data

# %% [markdown]
# Now that we have paired down our data, let's get a sense of our trip data.  We can use the `folium` Python library to plot a map of Manhattan, and our data.  First we must import `folium`, and then use the `Map` function to pass through a `location`, and `zoom_start`.  If a map isn't showing up below, copy and paste the command `pip install -r requirements.txt` into your terminal to install `folium` then try again.

# %%
import folium
manhattan_map = folium.Map(location=[40.7589, -73.9851], zoom_start=11)

# %%
manhattan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ok, now let's see how we could add a dot to mark a specific location.  We'll start with Times Square.

# %%
marker = folium.CircleMarker(location = [40.7589, -73.9851], radius=10)
marker.add_to(manhattan_map)

# %% [markdown]
# Above, we first create a marker.  Then we add that circle marker to the `manhattan_map` we created earlier.

# %%
manhattan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Do you see that blue dot near Time's Square?  That is our marker.
#
# So now that we can plot one marker on a map, we should have a sense of how we can plot many markers on a map to display our taxi ride data.  We simply plot a map, and then we add a marker for each location of a taxi trip.
#
# Now let's write some functions to allow us to plot maps and add markers a little more easily.

# %% [markdown]
# #### Writing some map plotting functions

# %% [markdown]
# As a first step towards this, note that the functions to create both a marker and map each take in a location as two element list, representing the latitude and longitude values.  Take another look:
#
# ```python
# marker = folium.CircleMarker(location = [40.7589, -73.9851])
# manhattan_map = folium.Map(location=[40.7589, -73.9851])
# ```
#
# So let's write a function called to create this two element list from a trip.  Write a function called `location` that  takes in a trip as an argument and returns a list where the first element is the latitude and the second is the longitude.  Remember that a location looks like the following:

# %%
first_trip = {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115,  'trip_distance': 18.38}
first_trip
# Out:
# {'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115,
#  'trip_distance': 18.38}

# %%
def location(trip):
    return list((trip['pickup_latitude'], trip['pickup_longitude']))

# %%
first_location = location(first_trip) # [40.64499, -73.78115]
first_location # [40.64499, -73.78115]
# Out:
# [40.64499, -73.78115]

# %% [markdown]
# Ok, now that we can turn a trip into a location, let's turn a location into a marker.  Write a function called `to_marker` that takes in a location (in the form of a list) as an argument, and returns a folium `circleMarker` for that location.  The radius of the marker should always equal 6.

# %%
def to_marker(location):
    return folium.CircleMarker(location = location, radius=6)

# %%
import json
times_square_marker = to_marker([40.7589, -73.9851])

times_square_marker and times_square_marker.location # [40.7589, -73.9851]

times_square_marker and json.loads(times_square_marker.options)['radius'] # 6
# Out:
# 6

# %%
times_square_marker and times_square_marker.location # [40.7589, -73.9851]
# Out:
# [40.7589, -73.9851]

# %% [markdown]
# Ok, now that we know how to produce a single marker, let's write a function to produce lots.  We can write a function called `markers_from_trips` that takes in a list of trips, and returns a marker object for each trip.

# %%
def markers_from_trips(l_trips):
    trips_with_marker = l_trips.copy()
    for i in trips_with_marker:
        return folium.CircleMarker(location = location, radius=6)

# %%
trip_markers = markers_from_trips(cleaned_trips)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-478-de7583b527a3> in <module>()
# ----> 1 trip_markers = markers_from_trips(cleaned_trips)
#
# <ipython-input-477-ecf199f6fb7e> in markers_from_trips(l_trips)
#       2     trips_with_marker = l_trips.copy()
#       3     for i in trips_with_marker:
# ----> 4         return folium.CircleMarker(location = location, radius=6)
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/folium/vector_layers.py in __init__(self, location, radius, popup, tooltip, **kwargs)
#     309     def __init__(self, location, radius=10, popup=None, tooltip=None, **kwargs):
#     310         super(CircleMarker, self).__init__(location=location, popup=popup,
# --> 311                                            tooltip=tooltip)
#     312         self._name = 'CircleMarker'
#     313         self.options = _parse_options(line=False, radius=radius, **kwargs)
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/folium/map.py in __init__(self, location, popup, tooltip, icon, draggable)
#     256         super(Marker, self).__init__()
#     257         self._name = 'Marker'
# --> 258         self.location = _validate_coordinates(location)
#     259         self.draggable = draggable
#     260         if icon is not None:
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/folium/utilities.py in _validate_coordinates(coordinates)
#      42 def _validate_coordinates(coordinates):
#      43     """Validates multiple coordinates for the various markers in folium."""
# ---> 44     if _isnan(coordinates):
#      45         raise ValueError('Location values cannot contain NaNs, '
#      46                          'got:\n{!r}'.format(coordinates))
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/folium/utilities.py in _isnan(values)
#      68 def _isnan(values):
#      69     """Check if there are NaNs values in the iterable."""
# ---> 70     return any(math.isnan(value) for value in _flatten(values))
#      71
#      72
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/folium/utilities.py in <genexpr>(.0)
#      68 def _isnan(values):
#      69     """Check if there are NaNs values in the iterable."""
# ---> 70     return any(math.isnan(value) for value in _flatten(values))
#      71
#      72
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/folium/utilities.py in _flatten(container)
#      58
#      59 def _flatten(container):
# ---> 60     for i in container:
#      61         if isinstance(i, (list, tuple, np.ndarray)):
#      62             for j in _flatten(i):
#
# TypeError: 'function' object is not iterable

# %%
cleaned_trips[0:4]
# Out:
# [{'trip_distance': 18.38,
#   'pickup_latitude': 40.64499,
#   'pickup_longitude': -73.78115},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.766931,
#   'pickup_longitude': -73.982098},
#  {'trip_distance': 4.5,
#   'pickup_latitude': 40.77773,
#   'pickup_longitude': -73.951902},
#  {'trip_distance': 2.4,
#   'pickup_latitude': 40.795678,
#   'pickup_longitude': -73.971049}]

# %%
marker.location
# Out:
# [40.7589, -73.9851]

# %%
trip_markers and len(trip_markers) # 1000
# Out:
# 1000

# %%
trip_markers and len(trip_markers) # 1000

list(map(lambda marker: marker.location, trip_markers[0:4]))
# [[40.64499, -73.78115],
#  [40.766931, -73.982098],
#  [40.77773, -73.951902],
#  [40.795678, -73.971049]]
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-444-26f67db15327> in <module>()
#       1 trip_markers and len(trip_markers) # 1000
#       2
# ----> 3 list(map(lambda marker: marker.location, trip_markers[0:4]))
#       4 # [[40.64499, -73.78115],
#       5 #  [40.766931, -73.982098],
#
# <ipython-input-444-26f67db15327> in <lambda>(marker)
#       1 trip_markers and len(trip_markers) # 1000
#       2
# ----> 3 list(map(lambda marker: marker.location, trip_markers[0:4]))
#       4 # [[40.64499, -73.78115],
#       5 #  [40.766931, -73.982098],
#
# AttributeError: 'dict' object has no attribute 'location'

# %% [markdown]
# Ok, now that we have a function that creates locations, and a function that creates markers, it is time to write a function to plot a map.
#
# Write a function called `map_from` that, provided the first argument of a list location and second argument an integer representing the `zoom_start`, returns a `folium` map the corresponding location and `zoom_start` attributes.
#
# > Hint: The following is how to write a map with folium:
# > ```python
#     folium.Map(location=location, zoom_start=zoom_amount)
# > ```

# %%
def map_from(location, zoom_amount):
    return folium.Map(location=location, zoom_start=zoom_amount)

# %%
times_square_map = map_from([40.7589, -73.9851], 15)
times_square_map and times_square_map.location # [40.7589, -73.9851]
times_square_map and times_square_map.zoom_start # 15
# Out:
# 15

# %%
times_square_marker and times_square_marker.add_to(times_square_map)
times_square_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now that we have a marker and a map, now let's write a function that adds a lot of markers to a map.  This function should add each marker in the list to the map object then return the updated map object.

# %%
manhattan_map = map_from([40.7589, -73.9851], 13)

# %%
def add_markers(markers, map_obj):
    for i in markers:
        marker = folium.CircleMarker(location = (i['pickup_latitude'], i['pickup_longitude']), radius=10)
        marker.add_to(map_obj)
    return map_obj

# %%
map_with_markers = add_markers(trip_markers, manhattan_map)

# %%
map_with_markers
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Using Nearest Neighbors

# %% [markdown]
# Ok, let's write a function that given a latitude and longitude will predict the distance for us.  We'll do this by first finding the nearest trips given a latitude and longitude.

# %% [markdown]
# Here we once again apply the nearest neighbors formula. As a first step, write a function named `distance_location` that calculates the distance in pickup location between two trips.

# %%
from math import sqrt

def distance_location(selected_trip, neighbor_trip):
    return sqrt((selected_trip['pickup_latitude'] - neighbor_trip['pickup_latitude'])**2 + (selected_trip['pickup_longitude'] - neighbor_trip['pickup_longitude'])**2)

# %%
from math import sqrt
def distance_location(selected_trip, neighbor_trip):
    return sqrt((selected_trip['pickup_latitude'] - neighbor_trip['pickup_latitude'])**2 
                + (selected_trip['pickup_longitude'] - neighbor_trip['pickup_longitude'])**2)

# %%
first_trip = {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115, 'trip_distance': 18.38}
second_trip = {'pickup_latitude': 40.766931, 'pickup_longitude': -73.982098, 'trip_distance': 1.3}
distance_first_and_second = distance_location(first_trip, second_trip)

distance_first_and_second and round(distance_first_and_second, 3) # 0.235
# Out:
# 0.235

# %% [markdown]
# Ok, next write a function called `distance_between_neighbors` that adds a new key-value pair, called `distance_from_selected`, that calculates the distance of the `neighbor_trip` from the `selected_trip`.

# %%
def distance_between_neighbors(selected_trip, neighbor_trip):
    return sqrt((selected_trip['pickup_latitude'] - neighbor_trip['pickup_latitude'])**2 
                + (selected_trip['pickup_longitude'] - neighbor_trip['pickup_longitude'])**2)

# %%
distance_between_neighbors(first_trip, second_trip)

# {'distance_from_selected': 0.23505256047318146,
#  'pickup_latitude': 40.766931,
#  'pickup_longitude': -73.982098,
#  'trip_distance': 1.3}
# Out:
# 0.23505256047318146

# %% [markdown]
# Ok, now our `neighbor_trip` has another attribute called `distance_from_selected`, that indicates the distance from the `neighbor_trip`'s pickup location from the `selected_trip`.

# %% [markdown]
# > ** Understand the data:** Our dictionary now has a few attributes, two of which say distance.  Let's make sure we understand the difference.
# > * **`distance_from_selected`:** This is our calculation of the distance of the neighbor's pickup location from the selected trip.
# > * **`trip_distance`:** This is the attribute we were provided initially.  It tells us the length of the neighbor's taxi trip from pickup to drop-off.

# %% [markdown]
# Next, write a function called `distance_all` that provided a list of neighbors, returns each of those neighbors with their respective `distance_from_selected` numbers.

# %%
def distance_all(selected_individual, neighbors):
    neighbors_2 = neighbors.copy()
    for i in neighbors_2:
        distance_from_select = sqrt((selected_individual['pickup_latitude'] - i['pickup_latitude'])**2 
                + (selected_individual['pickup_longitude'] - i['pickup_longitude'])**2)
        i.update( {'distance_from_selected': distance_from_select})
    return neighbors_2

# %%
cleaned_trips and distance_all(first_trip, cleaned_trips[0:4])
# Out:
# [{'trip_distance': 18.38,
#   'pickup_latitude': 40.64499,
#   'pickup_longitude': -73.78115,
#   'marker': <folium.vector_layers.CircleMarker at 0x7f13777696a0>,
#   'distance_from_selected': 0.0},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.766931,
#   'pickup_longitude': -73.982098,
#   'marker': <folium.vector_layers.CircleMarker at 0x7f1377a39e80>,
#   'distance_from_selected': 0.23505256047318146},
#  {'trip_distance': 4.5,
#   'pickup_latitude': 40.77773,
#   'pickup_longitude': -73.951902,
#   'marker': <folium.vector_layers.CircleMarker at 0x7f1378b4e2e8>,
#   'distance_from_selected': 0.2162779533470808},
#  {'trip_distance': 2.4,
#   'pickup_latitude': 40.795678,
#   'pickup_longitude': -73.971049,
#   'marker': <folium.vector_layers.CircleMarker at 0x7f1377769eb8>,
#   'distance_from_selected': 0.24242215976473674}]

# %% [markdown]
# Now write the nearest neighbors formula to calculate the distance of the `selected_trip` from all of the `cleaned_trips` in our dataset.  If no number is provided, it should return the top 3 neighbors.

# %%
def nearest_neighbors(selected_trip, trips, number = 3):
    cleaned_trips_2 = cleaned_trips.copy()
    for i in cleaned_trips_2:
        distance_from_select = sqrt((selected_trip['pickup_latitude'] - i['pickup_latitude'])**2 
                + (selected_trip['pickup_longitude'] - i['pickup_longitude'])**2)
        i.update( {'distance_from_selected': distance_from_select})

    sorted_clean_trips_2 = sorted(cleaned_trips_2, key = lambda i: i['distance_from_selected'])
    print(selected_trip)
    return sorted_clean_trips_2[:number]

# %%
new_trip = {'pickup_latitude': 40.64499,
'pickup_longitude': -73.78115,
'trip_distance': 18.38}

nearest_three_neighbors = nearest_neighbors(new_trip, cleaned_trips or [], number = 3)
nearest_three_neighbors
# [{'distance_from_selected': 0.0004569288784918792,
#   'pickup_latitude': 40.64483,
#   'pickup_longitude': -73.781578,
#   'trip_distance': 7.78},
#  {'distance_from_selected': 0.0011292165425673159,
#   'pickup_latitude': 40.644657,
#   'pickup_longitude': -73.782229,
#   'trip_distance': 12.7},
#  {'distance_from_selected': 0.0042359798158141185,
#   'pickup_latitude': 40.648509,
#   'pickup_longitude': -73.783508,
#   'trip_distance': 17.3}]
# Out:
# {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115, 'trip_distance': 18.38}
# [{'trip_distance': 18.38,
#   'pickup_latitude': 40.64499,
#   'pickup_longitude': -73.78115,
#   'marker': <folium.vector_layers.CircleMarker at 0x7f13777696a0>,
#   'distance_from_selected': 0.0},
#  {'trip_distance': 7.78,
#   'pickup_latitude': 40.64483,
#   'pickup_longitude': -73.781578,
#   'marker': <folium.vector_layers.CircleMarker at 0x7f1377ebb908>,
#   'distance_from_selected': 0.0004569288784918792},
#  {'trip_distance': 12.7,
#   'pickup_latitude': 40.644657,
#   'pickup_longitude': -73.782229,
#   'marker': <folium.vector_layers.CircleMarker at 0x7f1377a4ec50>,
#   'distance_from_selected': 0.0011292165425673159}]

# %% [markdown]
# Ok great! Now that we can provide a new trip location, and find the distances of the three nearest trips, we can take  calculate an estimate of the trip distance for that new trip location.
#
# We do so simply by calculating the average of it's nearest neighbors.

# %%
import statistics
def mean_distance(neighbors):
    nearest_distances = list(map(lambda neighbor: neighbor['trip_distance'], neighbors))
    return round(statistics.mean(nearest_distances), 3)

nearest_three_neighbors = nearest_neighbors(new_trip, cleaned_trips or [], number = 3)
distance_estimate_of_selected_trip = mean_distance(nearest_three_neighbors) # 12.593
distance_estimate_of_selected_trip
# Out:
# {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115, 'trip_distance': 18.38}
# 12.953

# %% [markdown]
# ### Choosing the correct number of neighbors

# %% [markdown]
# Now, as we know from the last lesson, one tricky element is to determine how many neighbors to choose, our $k$ value,  before calculating the average.  We want to choose our value of $k$ such that it properly matches actual data, and so that it applies to new data.  There are fancy formulas to ensure that we **train** our algorithm so that our formula is optimized for all data, but here let's see different $k$ values manually.  This is the gist of choosing our $k$ value:
#
# * If we choose a $k$ value too low, our formula will be too heavily influenced by a single neighbor, whereas if our $k$ value is too high, we will be choosing so many neighbors that our nearest neighbors formula will not be adjust enough according to locations.
#
# Ok, let's experiment with this.

# %% [markdown]
# First, let's choose a midtown location, to see what the trip distance would be.  A Google search reveals the coordinates of 51st and 7th avenue to be the following.

# %%
midtown_trip = dict(pickup_latitude=40.761710, pickup_longitude=-73.982760)

# %%
seven_closest = nearest_neighbors(midtown_trip, cleaned_trips, number = 7)
seven_closest
# [{'trip_distance': 0.58,
#   'pickup_latitude': 40.761372,
#   'pickup_longitude': -73.982602,
#   'distance_from_selected': 0.00037310588309379025},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.762444,
#   'pickup_longitude': -73.98244,
#   'distance_from_selected': 0.00080072217404248},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.762767,
#   'pickup_longitude': -73.982293,
#   'distance_from_selected': 0.0011555682584735844},
#  {'trip_distance': 8.3,
#   'pickup_latitude': 40.762868,
#   'pickup_longitude': -73.983233,
#   'distance_from_selected': 0.0012508768924205918},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 40.760057,
#   'pickup_longitude': -73.983502,
#   'distance_from_selected': 0.0018118976240381972},
#  {'trip_distance': 0.0,
#   'pickup_latitude': 40.760644,
#   'pickup_longitude': -73.984531,
#   'distance_from_selected': 0.002067074502774709},
#  {'trip_distance': 1.72,
#   'pickup_latitude': 40.762107,
#   'pickup_longitude': -73.98479,
#   'distance_from_selected': 0.0020684557041472677}]
# Out:
# {'pickup_latitude': 40.76171, 'pickup_longitude': -73.98276}
# [{'trip_distance': 0.58,
#   'pickup_latitude': 40.761372,
#   'pickup_longitude': -73.982602,
#   'marker': <folium.vector_layers.CircleMarker at 0x7f13776f3978>,
#   'distance_from_selected': 0.00037310588309379025},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.762444,
#   'pickup_longitude': -73.98244,
#   'marker': <folium.vector_layers.CircleMarker at 0x7f1378140400>,
#   'distance_from_selected': 0.00080072217404248},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.762767,
#   'pickup_longitude': -73.982293,
#   'marker': <folium.vector_layers.CircleMarker at 0x7f1378118a20>,
#   'distance_from_selected': 0.0011555682584735844},
#  {'trip_distance': 8.3,
#   'pickup_latitude': 40.762868,
#   'pickup_longitude': -73.983233,
#   'marker': <folium.vector_layers.CircleMarker at 0x7f1377618e48>,
#   'distance_from_selected': 0.0012508768924205918},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 40.760057,
#   'pickup_longitude': -73.983502,
#   'marker': <folium.vector_layers.CircleMarker at 0x7f13776f3e80>,
#   'distance_from_selected': 0.0018118976240381972},
#  {'trip_distance': 0.0,
#   'pickup_latitude': 40.760644,
#   'pickup_longitude': -73.984531,
#   'marker': <folium.vector_layers.CircleMarker at 0x7f1377ebb550>,
#   'distance_from_selected': 0.002067074502774709},
#  {'trip_distance': 1.72,
#   'pickup_latitude': 40.762107,
#   'pickup_longitude': -73.98479,
#   'marker': <folium.vector_layers.CircleMarker at 0x7f137770b0b8>,
#   'distance_from_selected': 0.0020684557041472677}]

# %% [markdown]
# Looking at the `distance_from_selected` it appears that our our trips are still fairly close to our selected trip.  Notice that most of the data is within a distance of .002 away, so going to the top 7 nearest neighbors didn't seem to give us neighbors too far from each other, which is a good sign.
#
# Still, it's hard to know what distance in latitude and longitude really look like, so let's map the data.

# %%
midtown_location = location(midtown_trip) # [40.76171, -73.98276]
midtown_map = map_from(midtown_location, 16)
closest_markers = markers_from_trips(seven_closest)

add_markers(closest_markers, midtown_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ok.  These locations stay fairly close to our estimated location of 51st street and 7th Avenue.  So they could be a good estimate of a trip distance.

# %%
mean_distance(seven_closest) # 2.009
# Out:
# 2.009

# %% [markdown]
# Ok, now let's try a different location

# %%
charging_bull_closest = nearest_neighbors({'pickup_latitude': 40.7049, 'pickup_longitude': -74.0137}, cleaned_trips, number = 12)
# Out:
# {'pickup_latitude': 40.7049, 'pickup_longitude': -74.0137}

# %%
mean_distance(charging_bull_closest) # 3.145
# Out:
# 3.145

# %% [markdown]
# Ok, so there appears to be a significant difference between choosing a location near Times Square versus choosing a location at Wall Street.

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, we used the nearest neighbors function to predict the length of a taxi ride.  To do so, we selected a location, then found a number of taxi rides closest to that location, and finally took the average trip lengths of the nearest taxi rides to find an estimate of the new ride's trip length.  You can see that even with just a little bit of math and programming we can begin to make meaningful predictions with data.
